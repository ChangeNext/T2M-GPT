# %%
import os
import json

import torch
os.chdir("/workspace/")
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import models.vqvae as vqvae
# import options.option_vq as option_vq
import utils.utils_model as utils_model
from dataset import dataset_TM_eval
import utils.eval_trans as eval_trans
from options.get_eval_option import get_opt
from models.evaluator_wrapper import EvaluatorModelWrapper
import warnings
warnings.filterwarnings('ignore')

# %%
import easydict

opt = easydict.EasyDict({
    "dataname": "t2m",
    "batch_size": 256,
    "window_size": 64,
    "total_iter": 300000,
    "warm_up_iter": 1000,
    "lr": 2e-4,
    "lr_scheduler": [200000],#[50000, 400000],
    "gamma": 0.05,
    "weight_decay": 0.0,
    "commit": 0.02,
    "loss_vel": 0.5,
    "recons_loss": "l1_smooth",
    "code_dim": 512,
    "nb_code": 512,
    "mu": 0.99,
    "down_t": 2,
    "stride_t": 2,
    "width": 512,
    "depth": 3,
    "dilation_growth_rate": 3,
    "output_emb_width": 512,
    "vq_act": "relu",
    "vq_norm": None,
    "quantizer": "ema_reset",
    "beta": 1.0,
    "resume_pth": None,
    "resume_gpt": None,
    "out_dir": "output_vqfinal/TEST_VQVAE/eval",
    "results_dir": "visual_results/",
    "visual_name": "baseline",
    "exp_name": "TEST_VQVAE/eval",
    "print_iter": 200,
    "eval_iter": 1000,
    "seed": 123,
    "vis_gt": False,
    "nb_vis": 20,
    "nb_joints" : 0,
    "resume_pth" : "output_vqfinal/VQ-VAE/eval/net_last.pth"
})

# %%
logger = utils_model.get_logger(opt.out_dir)
writer = SummaryWriter(opt.out_dir)
logger.info(json.dumps(vars(opt), indent=4, sort_keys=True))
# Out:
# 2023-06-19 07:34:04,634 INFO {
#     "batch_size": 256,
#     "beta": 1.0,
#     "code_dim": 512,
#     "commit": 0.02,
#     "dataname": "t2m",
#     "depth": 3,
#     "dilation_growth_rate": 3,
#     "down_t": 2,
#     "eval_iter": 1000,
#     "exp_name": "TEST_VQVAE/eval",
#     "gamma": 0.05,
#     "loss_vel": 0.5,
#     "lr": 0.0002,
#     "lr_scheduler": [
#         200000
#     ],
#     "mu": 0.99,
#     "nb_code": 512,
#     "nb_joints": 0,
#     "nb_vis": 20,
#     "out_dir": "output_vqfinal/TEST_VQVAE/eval",
#     "output_emb_width": 512,
#     "print_iter": 200,
#     "quantizer": "ema_reset",
#     "recons_loss": "l1_smooth",
#     "results_dir": "visual_results/",
#     "resume_gpt": null,
#     "resume_pth": "output_vqfinal/VQ-VAE/eval/net_last.pth",
#     "seed": 123,
#     "stride_t": 2,
#     "total_iter": 300000,
#     "vis_gt": false,
#     "visual_name": "baseline",
#     "vq_act": "relu",
#     "vq_norm": null,
#     "warm_up_iter": 1000,
#     "weight_decay": 0.0,
#     "width": 512,
#     "window_size": 64
# }

# %%
from utils.word_vectorizer import WordVectorizer
w_vectorizer = WordVectorizer('./glove', 'our_vab')

# %%
dataset_opt_path = 'checkpoints/kit/Comp_v6_KLD005/opt.txt' if opt.dataname == 'kit' else 'checkpoints/t2m/Comp_v6_KLD005/opt.txt'

# %%
wrapper_opt = get_opt(dataset_opt_path, torch.device('cuda'))
eval_wrapper = EvaluatorModelWrapper(wrapper_opt)
# Out:
# Reading checkpoints/t2m/Comp_v6_KLD005/opt.txt
# Loading Evaluation Model Wrapper (Epoch 28) Completed!!

# %%
opt.nb_joints = 21 if opt.dataname == 'kit' else 22

val_loader = dataset_TM_eval.DATALoader(opt.dataname, True, 32, w_vectorizer, unit_length=2**opt.down_t)

##### ---- Network ---- #####
net = vqvae.HumanVQVAE(opt, ## use opt to define different parameters in different quantizers
                       opt.nb_code,
                       opt.code_dim,
                       opt.output_emb_width,
                       opt.down_t,
                       opt.stride_t,
                       opt.width,
                       opt.depth,
                       opt.dilation_growth_rate,
                       opt.vq_act,
                       opt.vq_norm)
# Out:
# 100%|██████████| 4384/4384 [00:00<00:00, 5026.18it/s]
# Pointer Pointing at 0

# %%
if opt.resume_pth : 
    logger.info('loading checkpoint from {}'.format(opt.resume_pth))
    ckpt = torch.load(opt.resume_pth, map_location='cpu')
    net.load_state_dict(ckpt['net'], strict=True)
net.train()
net.cuda()
# Out:
# 2023-06-19 07:34:11,655 INFO loading checkpoint from output_vqfinal/VQ-VAE/eval/net_last.pth
# HumanVQVAE(
#   (vqvae): VQVAE_251(
#     (encoder): Encoder(
#       (model): Sequential(
#         (0): Conv1d(263, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): ReLU()
#         (2): Sequential(
#           (0): Conv1d(512, 512, kernel_size=(4,), stride=(2,), padding=(1,))
#           (1): Resnet1D(
#             (model): Sequential(
#               (0): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(9,), dilation=(9,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (1): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (2): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#             )
#           )
#         )
#         (3): Sequential(
#           (0): Conv1d(512, 512, kernel_size=(4,), stride=(2,), padding=(1,))
#           (1): Resnet1D(
#             (model): Sequential(
#               (0): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(9,), dilation=(9,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (1): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (2): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#             )
#           )
#         )
#         (4): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (decoder): Decoder(
#       (model): Sequential(
#         (0): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): ReLU()
#         (2): Sequential(
#           (0): Resnet1D(
#             (model): Sequential(
#               (0): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(9,), dilation=(9,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (1): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (2): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#             )
#           )
#           (1): Upsample(scale_factor=2.0, mode=nearest)
#           (2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (3): Sequential(
#           (0): Resnet1D(
#             (model): Sequential(
#               (0): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(9,), dilation=(9,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (1): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#               (2): ResConv1DBlock(
#                 (norm1): Identity()
#                 (norm2): Identity()
#                 (activation1): ReLU()
#                 (activation2): ReLU()
#                 (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#               )
#             )
#           )
#           (1): Upsample(scale_factor=2.0, mode=nearest)
#           (2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (4): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (5): ReLU()
#         (6): Conv1d(512, 263, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (quantizer): QuantizeEMAReset()
#   )
# )

# %%
fid = []
div = []
top1 = []
top2 = []
top3 = []
matching = []
repeat_time = 20
for i in range(repeat_time):
    best_fid, best_iter, best_div, best_top1, best_top2, best_top3, best_matching, writer, logger = eval_trans.evaluation_vqvae(opt.out_dir, val_loader, net, logger, writer, 0, best_fid=1000, best_iter=0, best_div=100, best_top1=0, best_top2=0, best_top3=0, best_matching=100, eval_wrapper=eval_wrapper, draw=True, savegif=True, save=False, savenpy=False)
    fid.append(best_fid)
    div.append(best_div)
    top1.append(best_top1)
    top2.append(best_top2)
    top3.append(best_top3)
    matching.append(best_matching)
print('final result:')
print('fid: ', sum(fid)/repeat_time)
print('div: ', sum(div)/repeat_time)
print('top1: ', sum(top1)/repeat_time)
print('top2: ', sum(top2)/repeat_time)
print('top3: ', sum(top3)/repeat_time)
print('matching: ', sum(matching)/repeat_time)

fid = np.array(fid)
div = np.array(div)
top1 = np.array(top1)
top2 = np.array(top2)
top3 = np.array(top3)
matching = np.array(matching)
msg_final = f"FID. {np.mean(fid):.3f}, conf. {np.std(fid)*1.96/np.sqrt(repeat_time):.3f}, Diversity. {np.mean(div):.3f}, conf. {np.std(div)*1.96/np.sqrt(repeat_time):.3f}, TOP1. {np.mean(top1):.3f}, conf. {np.std(top1)*1.96/np.sqrt(repeat_time):.3f}, TOP2. {np.mean(top2):.3f}, conf. {np.std(top2)*1.96/np.sqrt(repeat_time):.3f}, TOP3. {np.mean(top3):.3f}, conf. {np.std(top3)*1.96/np.sqrt(repeat_time):.3f}, Matching. {np.mean(matching):.3f}, conf. {np.std(matching)*1.96/np.sqrt(repeat_time):.3f}"
logger.info(msg_final)
# Out:
# 2023-06-19 07:34:41,908 INFO --> 	 Eva. Iter 0 :, FID. 0.1140, Diversity Real. 9.4657, Diversity. 9.6670, R_precision_real. [0.51228448 0.71142241 0.80732759], R_precision. [0.49633621 0.69568966 0.79331897], matching_score_real. 2.977429518206366, matching_score_pred. 3.0757760343880487
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:36:47,414 INFO --> --> 	 FID Improved from 1000.00000 to 0.11401 !!!
# 2023-06-19 07:36:47,415 INFO --> --> 	 Diversity Improved from 100.00000 to 9.66696 !!!
# 2023-06-19 07:36:47,415 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4963 !!!
# 2023-06-19 07:36:47,415 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6957 !!!
# 2023-06-19 07:36:47,416 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7933 !!!
# 2023-06-19 07:36:47,416 INFO --> --> 	 matching_score Improved from 100.00000 to 3.07578 !!!
# 2023-06-19 07:37:17,673 INFO --> 	 Eva. Iter 0 :, FID. 0.1102, Diversity Real. 9.6590, Diversity. 9.6469, R_precision_real. [0.51702586 0.7075431  0.79633621], R_precision. [0.50280172 0.69030172 0.7875    ], matching_score_real. 2.942037316026359, matching_score_pred. 3.037121554078727
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:38:49,866 INFO --> --> 	 FID Improved from 1000.00000 to 0.11015 !!!
# 2023-06-19 07:38:49,866 INFO --> --> 	 Diversity Improved from 100.00000 to 9.64687 !!!
# 2023-06-19 07:38:49,867 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5028 !!!
# 2023-06-19 07:38:49,867 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6903 !!!
# 2023-06-19 07:38:49,867 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7875 !!!
# 2023-06-19 07:38:49,867 INFO --> --> 	 matching_score Improved from 100.00000 to 3.03712 !!!
# 2023-06-19 07:39:18,942 INFO --> 	 Eva. Iter 0 :, FID. 0.1111, Diversity Real. 9.2687, Diversity. 10.0180, R_precision_real. [0.51077586 0.7        0.80064655], R_precision. [0.48081897 0.68491379 0.78232759], matching_score_real. 2.9675670771763243, matching_score_pred. 3.0680168316282077
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:41:12,838 INFO --> --> 	 FID Improved from 1000.00000 to 0.11108 !!!
# 2023-06-19 07:41:12,838 INFO --> --> 	 Diversity Improved from 100.00000 to 10.01804 !!!
# 2023-06-19 07:41:12,838 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4808 !!!
# 2023-06-19 07:41:12,839 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6849 !!!
# 2023-06-19 07:41:12,839 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7823 !!!
# 2023-06-19 07:41:12,840 INFO --> --> 	 matching_score Improved from 100.00000 to 3.06802 !!!
# 2023-06-19 07:41:42,430 INFO --> 	 Eva. Iter 0 :, FID. 0.1088, Diversity Real. 9.4861, Diversity. 10.0182, R_precision_real. [0.52219828 0.69913793 0.79568966], R_precision. [0.5049569  0.68900862 0.78965517], matching_score_real. 2.96063830441442, matching_score_pred. 3.066571773331741
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:43:59,657 INFO --> --> 	 FID Improved from 1000.00000 to 0.10878 !!!
# 2023-06-19 07:43:59,658 INFO --> --> 	 Diversity Improved from 100.00000 to 10.01820 !!!
# 2023-06-19 07:43:59,659 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5050 !!!
# 2023-06-19 07:43:59,659 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6890 !!!
# 2023-06-19 07:43:59,659 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7897 !!!
# 2023-06-19 07:43:59,660 INFO --> --> 	 matching_score Improved from 100.00000 to 3.06657 !!!
# 2023-06-19 07:44:28,356 INFO --> 	 Eva. Iter 0 :, FID. 0.1101, Diversity Real. 9.8330, Diversity. 9.8305, R_precision_real. [0.51185345 0.70625    0.79784483], R_precision. [0.50107759 0.69159483 0.79181034], matching_score_real. 2.9612331012199666, matching_score_pred. 3.0560503976098423
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:46:24,668 INFO --> --> 	 FID Improved from 1000.00000 to 0.11006 !!!
# 2023-06-19 07:46:24,669 INFO --> --> 	 Diversity Improved from 100.00000 to 9.83045 !!!
# 2023-06-19 07:46:24,669 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5011 !!!
# 2023-06-19 07:46:24,670 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6916 !!!
# 2023-06-19 07:46:24,670 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7918 !!!
# 2023-06-19 07:46:24,670 INFO --> --> 	 matching_score Improved from 100.00000 to 3.05605 !!!
# 2023-06-19 07:46:53,896 INFO --> 	 Eva. Iter 0 :, FID. 0.1088, Diversity Real. 9.4057, Diversity. 9.4856, R_precision_real. [0.51228448 0.70581897 0.80258621], R_precision. [0.49310345 0.68642241 0.78599138], matching_score_real. 2.9635633337086644, matching_score_pred. 3.0519601345062255
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:49:01,365 INFO --> --> 	 FID Improved from 1000.00000 to 0.10877 !!!
# 2023-06-19 07:49:01,366 INFO --> --> 	 Diversity Improved from 100.00000 to 9.48561 !!!
# 2023-06-19 07:49:01,366 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4931 !!!
# 2023-06-19 07:49:01,367 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6864 !!!
# 2023-06-19 07:49:01,367 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7860 !!!
# 2023-06-19 07:49:01,368 INFO --> --> 	 matching_score Improved from 100.00000 to 3.05196 !!!
# 2023-06-19 07:49:29,917 INFO --> 	 Eva. Iter 0 :, FID. 0.1136, Diversity Real. 9.5013, Diversity. 9.3303, R_precision_real. [0.51099138 0.70862069 0.79741379], R_precision. [0.49439655 0.69396552 0.79094828], matching_score_real. 2.9809565527685757, matching_score_pred. 3.0812876652026997
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:51:11,583 INFO --> --> 	 FID Improved from 1000.00000 to 0.11360 !!!
# 2023-06-19 07:51:11,584 INFO --> --> 	 Diversity Improved from 100.00000 to 9.33026 !!!
# 2023-06-19 07:51:11,584 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4944 !!!
# 2023-06-19 07:51:11,584 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6940 !!!
# 2023-06-19 07:51:11,585 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7909 !!!
# 2023-06-19 07:51:11,585 INFO --> --> 	 matching_score Improved from 100.00000 to 3.08129 !!!
# 2023-06-19 07:51:40,944 INFO --> 	 Eva. Iter 0 :, FID. 0.1138, Diversity Real. 9.7522, Diversity. 9.8851, R_precision_real. [0.51551724 0.70237069 0.7987069 ], R_precision. [0.49439655 0.69202586 0.78728448], matching_score_real. 2.9636073671538252, matching_score_pred. 3.0679746463381012
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:53:33,124 INFO --> --> 	 FID Improved from 1000.00000 to 0.11379 !!!
# 2023-06-19 07:53:33,125 INFO --> --> 	 Diversity Improved from 100.00000 to 9.88512 !!!
# 2023-06-19 07:53:33,125 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4944 !!!
# 2023-06-19 07:53:33,125 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6920 !!!
# 2023-06-19 07:53:33,126 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7873 !!!
# 2023-06-19 07:53:33,126 INFO --> --> 	 matching_score Improved from 100.00000 to 3.06797 !!!
# 2023-06-19 07:54:02,236 INFO --> 	 Eva. Iter 0 :, FID. 0.1094, Diversity Real. 10.0646, Diversity. 9.6495, R_precision_real. [0.51681034 0.70840517 0.80215517], R_precision. [0.5125     0.69396552 0.78836207], matching_score_real. 2.9418620339755353, matching_score_pred. 3.0373401954256254
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:56:04,753 INFO --> --> 	 FID Improved from 1000.00000 to 0.10943 !!!
# 2023-06-19 07:56:04,753 INFO --> --> 	 Diversity Improved from 100.00000 to 9.64949 !!!
# 2023-06-19 07:56:04,753 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5125 !!!
# 2023-06-19 07:56:04,754 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6940 !!!
# 2023-06-19 07:56:04,754 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7884 !!!
# 2023-06-19 07:56:04,755 INFO --> --> 	 matching_score Improved from 100.00000 to 3.03734 !!!
# 2023-06-19 07:56:34,064 INFO --> 	 Eva. Iter 0 :, FID. 0.1089, Diversity Real. 9.5606, Diversity. 10.2570, R_precision_real. [0.49741379 0.69784483 0.79051724], R_precision. [0.49094828 0.68038793 0.77931034], matching_score_real. 2.9910370464982656, matching_score_pred. 3.088810422502715
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 07:58:14,414 INFO --> --> 	 FID Improved from 1000.00000 to 0.10892 !!!
# 2023-06-19 07:58:14,415 INFO --> --> 	 Diversity Improved from 100.00000 to 10.25704 !!!
# 2023-06-19 07:58:14,415 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4909 !!!
# 2023-06-19 07:58:14,416 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6804 !!!
# 2023-06-19 07:58:14,416 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7793 !!!
# 2023-06-19 07:58:14,416 INFO --> --> 	 matching_score Improved from 100.00000 to 3.08881 !!!
# 2023-06-19 07:58:43,477 INFO --> 	 Eva. Iter 0 :, FID. 0.1105, Diversity Real. 9.1835, Diversity. 9.5366, R_precision_real. [0.52219828 0.71681034 0.8112069 ], R_precision. [0.5112069  0.69849138 0.79418103], matching_score_real. 2.9159285545349123, matching_score_pred. 3.0210030259757206
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:00:58,307 INFO --> --> 	 FID Improved from 1000.00000 to 0.11050 !!!
# 2023-06-19 08:00:58,308 INFO --> --> 	 Diversity Improved from 100.00000 to 9.53656 !!!
# 2023-06-19 08:00:58,309 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5112 !!!
# 2023-06-19 08:00:58,309 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6985 !!!
# 2023-06-19 08:00:58,309 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7942 !!!
# 2023-06-19 08:00:58,309 INFO --> --> 	 matching_score Improved from 100.00000 to 3.02100 !!!
# 2023-06-19 08:01:28,359 INFO --> 	 Eva. Iter 0 :, FID. 0.1127, Diversity Real. 9.1804, Diversity. 9.8838, R_precision_real. [0.51293103 0.70280172 0.79612069], R_precision. [0.49741379 0.68814655 0.78405172], matching_score_real. 2.9607790601664576, matching_score_pred. 3.06561530705156
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:02:43,311 INFO --> --> 	 FID Improved from 1000.00000 to 0.11270 !!!
# 2023-06-19 08:02:43,312 INFO --> --> 	 Diversity Improved from 100.00000 to 9.88376 !!!
# 2023-06-19 08:02:43,313 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4974 !!!
# 2023-06-19 08:02:43,313 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6881 !!!
# 2023-06-19 08:02:43,313 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7841 !!!
# 2023-06-19 08:02:43,314 INFO --> --> 	 matching_score Improved from 100.00000 to 3.06562 !!!
# 2023-06-19 08:03:12,696 INFO --> 	 Eva. Iter 0 :, FID. 0.1112, Diversity Real. 9.4094, Diversity. 9.6545, R_precision_real. [0.50517241 0.69331897 0.79741379], R_precision. [0.49375    0.68340517 0.77909483], matching_score_real. 2.97491129349018, matching_score_pred. 3.075077012489582
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:04:51,133 INFO --> --> 	 FID Improved from 1000.00000 to 0.11120 !!!
# 2023-06-19 08:04:51,133 INFO --> --> 	 Diversity Improved from 100.00000 to 9.65449 !!!
# 2023-06-19 08:04:51,134 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4938 !!!
# 2023-06-19 08:04:51,134 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6834 !!!
# 2023-06-19 08:04:51,134 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7791 !!!
# 2023-06-19 08:04:51,134 INFO --> --> 	 matching_score Improved from 100.00000 to 3.07508 !!!
# 2023-06-19 08:05:21,007 INFO --> 	 Eva. Iter 0 :, FID. 0.1103, Diversity Real. 9.0944, Diversity. 9.5304, R_precision_real. [0.50818966 0.70107759 0.79633621], R_precision. [0.48922414 0.68232759 0.77758621], matching_score_real. 2.9869375179553854, matching_score_pred. 3.0838764651068327
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:07:13,241 INFO --> --> 	 FID Improved from 1000.00000 to 0.11025 !!!
# 2023-06-19 08:07:13,242 INFO --> --> 	 Diversity Improved from 100.00000 to 9.53036 !!!
# 2023-06-19 08:07:13,242 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4892 !!!
# 2023-06-19 08:07:13,243 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6823 !!!
# 2023-06-19 08:07:13,243 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7776 !!!
# 2023-06-19 08:07:13,243 INFO --> --> 	 matching_score Improved from 100.00000 to 3.08388 !!!
# 2023-06-19 08:07:42,700 INFO --> 	 Eva. Iter 0 :, FID. 0.1095, Diversity Real. 9.5262, Diversity. 9.5842, R_precision_real. [0.51918103 0.7        0.79547414], R_precision. [0.5012931  0.6875     0.78103448], matching_score_real. 2.957215194044442, matching_score_pred. 3.0517320534278607
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:09:32,794 INFO --> --> 	 FID Improved from 1000.00000 to 0.10954 !!!
# 2023-06-19 08:09:32,795 INFO --> --> 	 Diversity Improved from 100.00000 to 9.58416 !!!
# 2023-06-19 08:09:32,795 INFO --> --> 	 Top1 Improved from 0.0000 to 0.5013 !!!
# 2023-06-19 08:09:32,795 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6875 !!!
# 2023-06-19 08:09:32,796 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7810 !!!
# 2023-06-19 08:09:32,796 INFO --> --> 	 matching_score Improved from 100.00000 to 3.05173 !!!
# 2023-06-19 08:10:03,026 INFO --> 	 Eva. Iter 0 :, FID. 0.1098, Diversity Real. 8.9605, Diversity. 9.7136, R_precision_real. [0.51594828 0.70948276 0.80043103], R_precision. [0.49396552 0.6887931  0.78857759], matching_score_real. 2.962742431410428, matching_score_pred. 3.0646301072219324
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:11:39,383 INFO --> --> 	 FID Improved from 1000.00000 to 0.10975 !!!
# 2023-06-19 08:11:39,384 INFO --> --> 	 Diversity Improved from 100.00000 to 9.71356 !!!
# 2023-06-19 08:11:39,384 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4940 !!!
# 2023-06-19 08:11:39,385 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6888 !!!
# 2023-06-19 08:11:39,385 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7886 !!!
# 2023-06-19 08:11:39,385 INFO --> --> 	 matching_score Improved from 100.00000 to 3.06463 !!!
# 2023-06-19 08:12:08,696 INFO --> 	 Eva. Iter 0 :, FID. 0.1140, Diversity Real. 9.4362, Diversity. 9.7824, R_precision_real. [0.5075431  0.70711207 0.80150862], R_precision. [0.49461207 0.69310345 0.78512931], matching_score_real. 2.985083691827182, matching_score_pred. 3.0814462349332614
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:13:59,349 INFO --> --> 	 FID Improved from 1000.00000 to 0.11404 !!!
# 2023-06-19 08:13:59,349 INFO --> --> 	 Diversity Improved from 100.00000 to 9.78242 !!!
# 2023-06-19 08:13:59,350 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4946 !!!
# 2023-06-19 08:13:59,350 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6931 !!!
# 2023-06-19 08:13:59,350 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7851 !!!
# 2023-06-19 08:13:59,351 INFO --> --> 	 matching_score Improved from 100.00000 to 3.08145 !!!
# 2023-06-19 08:14:28,832 INFO --> 	 Eva. Iter 0 :, FID. 0.1114, Diversity Real. 9.5559, Diversity. 10.0714, R_precision_real. [0.50775862 0.70215517 0.79784483], R_precision. [0.49827586 0.69288793 0.78512931], matching_score_real. 3.0039144252908643, matching_score_pred. 3.094383220014901
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:16:25,733 INFO --> --> 	 FID Improved from 1000.00000 to 0.11140 !!!
# 2023-06-19 08:16:25,734 INFO --> --> 	 Diversity Improved from 100.00000 to 10.07139 !!!
# 2023-06-19 08:16:25,734 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4983 !!!
# 2023-06-19 08:16:25,734 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6929 !!!
# 2023-06-19 08:16:25,735 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7851 !!!
# 2023-06-19 08:16:25,735 INFO --> --> 	 matching_score Improved from 100.00000 to 3.09438 !!!
# 2023-06-19 08:16:54,603 INFO --> 	 Eva. Iter 0 :, FID. 0.1157, Diversity Real. 9.6288, Diversity. 9.8631, R_precision_real. [0.51637931 0.71034483 0.80431034], R_precision. [0.49590517 0.69051724 0.7875    ], matching_score_real. 2.94795450177686, matching_score_pred. 3.054094988724281
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:18:50,565 INFO --> --> 	 FID Improved from 1000.00000 to 0.11573 !!!
# 2023-06-19 08:18:50,566 INFO --> --> 	 Diversity Improved from 100.00000 to 9.86306 !!!
# 2023-06-19 08:18:50,567 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4959 !!!
# 2023-06-19 08:18:50,567 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6905 !!!
# 2023-06-19 08:18:50,568 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7875 !!!
# 2023-06-19 08:18:50,568 INFO --> --> 	 matching_score Improved from 100.00000 to 3.05409 !!!
# 2023-06-19 08:19:19,809 INFO --> 	 Eva. Iter 0 :, FID. 0.1100, Diversity Real. 9.4952, Diversity. 10.0122, R_precision_real. [0.50043103 0.70064655 0.79288793], R_precision. [0.48297414 0.68211207 0.77844828], matching_score_real. 2.9808717431693244, matching_score_pred. 3.0712123755750986
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# moviepy is installed, but can't import moviepy.editor. Some packages could be missing [imageio, requests]
# 2023-06-19 08:21:12,649 INFO --> --> 	 FID Improved from 1000.00000 to 0.10995 !!!
# 2023-06-19 08:21:12,650 INFO --> --> 	 Diversity Improved from 100.00000 to 10.01217 !!!
# 2023-06-19 08:21:12,650 INFO --> --> 	 Top1 Improved from 0.0000 to 0.4830 !!!
# 2023-06-19 08:21:12,650 INFO --> --> 	 Top2 Improved from 0.0000 to 0.6821 !!!
# 2023-06-19 08:21:12,651 INFO --> --> 	 Top3 Improved from 0.0000 to 0.7784 !!!
# 2023-06-19 08:21:12,651 INFO --> --> 	 matching_score Improved from 100.00000 to 3.07121 !!!
# final result:
# fid:  0.11118357588838138
# div:  9.770997714996337
# top1:  0.4964978448275863
# top2:  0.6892780172413794
# top3:  0.7858620689655171
# matching:  3.064699022276648
# 2023-06-19 08:21:12,655 INFO FID. 0.111, conf. 0.001, Diversity. 9.771, conf. 0.099, TOP1. 0.496, conf. 0.003, TOP2. 0.689, conf. 0.002, TOP3. 0.786, conf. 0.002, Matching. 3.065, conf. 0.008
